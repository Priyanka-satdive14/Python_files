# %%
import os
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
RANDOM_STATE = 24
np.random.seed(RANDOM_STATE)
CMAP = plt.cm.rainbow

# %%
titanic_file = os.path.join('Titanic-Dataset.csv')

data_df = pd.read_csv(titanic_file)

data_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
for col in data_df.columns:
    print(f'{col}:{data_df[col].unique}\n')
# Out:
# PassengerId:<bound method Series.unique of 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64>
#
# Survived:<bound method Series.unique of 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64>
#
# Pclass:<bound method Series.unique of 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64>
#
# Name:<bound method Series.unique of 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# ...

# %%
data_df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
data_df.iloc[[413,415,284]]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 413          414         0       2           Cunningham, Mr. Alfred Fleming
# 415          416         0       3  Meek, Mrs. Thomas (Annie Louise Rowley)
# 284          285         0       1               Smith, Mr. Richard William
#
#         Sex  Age  SibSp  Parch  Ticket   Fare Cabin Embarked
# 413    male  NaN      0      0  239853   0.00   NaN        S
# 415  female  NaN      0      0  343095   8.05   NaN        S
# 284    male  NaN      0      0  113056  26.00   A19        S

# %%
data_df=data_df.drop([413,415,284],axis = 0).copy()

data_df.reset_index(inplace=True,drop=True)
data_df.shape
# Out:
# (888, 12)

# %%
sns.pairplot(data_df)

# %%
data_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
columns_sels = ['Ticket','PassengerId','Parch']
scaler = MinMaxScaler()
feature_df = data_df[columns_sels].copy()

# %%
feature_df = pd.DataFrame(data=scaler.fit_transform(feature_df),
                          columns=columns_sels)
feature_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16100\1329139351.py in ?()
# ----> 1 feature_df = pd.DataFrame(data=scaler.fit_transform(feature_df),
#       2                           columns=columns_sels)
#       3 feature_df.head()
#
# c:\Users\PRIYANKA\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# c:\Users\PRIYANKA\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
# ...

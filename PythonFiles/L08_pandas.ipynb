# %% [markdown]
# ## Pandas

# %%
#!/usr/bin/env python3
# -*- coding:utf-8 -*-

# %%
import pandas as pd #make rows and column data

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
num_list =[1,2,3,4,5]
s = pd.Series(num_list) #to give indexno to list it always make it in column wise
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#to change index numbers myst be unique and value also unique
num_idx = ['a','b','c','d','e']
s = pd.Series(num_list,index=num_idx)
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
dct ={'name':'pks', 'city':'Pune','country':'india'} #colum data must be same always 
s=pd.Series(dct)
s
# Out:
# name         pks
# city        Pune
# country    india
# dtype: object

# %%
data = [[1,2,3],[4,5,6],[7,8,9]]
data_df =pd.DataFrame(data)  #dataframe=give index number  to colmn as well as row 
data_df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
data = [[1,2,3],[4,5,6],[7,'80',9]]
data_df =pd.DataFrame(data, columns=['cl1','cl2','cl3']) # dataframe=give index name  to colmn like col1 col2 and supply data  
data_df
# Out:
#    cl1 cl2  cl3
# 0    1   2    3
# 1    4   5    6
# 2    7  80    9

# %%
dct ={'name':['pks','AAA','BBB'], 
      'city':['Pune','Mumbai','Indore'],
      'country':['india','I','Ind']} #when we give dic to dataframe it will take key->column name and data->row
pd.DataFrame(dct)
# Out:
#   name    city country
# 0  pks    Pune   india
# 1  AAA  Mumbai       I
# 2  BBB  Indore     Ind

# %%
dct ={'name':['pks','Soham','Arti'], 
      'city':['Pune','London','Stockholm'],
      'country':['india','Uk','sweden']}
data_df = pd.DataFrame(dct)
data_df
# Out:
#     name       city country
# 0    pks       Pune   india
# 1  Soham     London      Uk
# 2   Arti  Stockholm  sweden

# %%
data_df['weight'] = [74,78,61]
data_df['height'] = [174,178,161]
data_df #add data into existing dic 2 new column added
# Out:
#     name       city country  weight  height
# 0    pks       Pune   india      74     174
# 1  Soham     London      Uk      78     178
# 2   Arti  Stockholm  sweden      61     161

# %%
#change height into cm
data_df['height'] = data_df['height']*0.01

# %%
#bmi=weight/(height**2)
data_df['bmi'] = data_df['weight']/data_df['height']**2
data_df
# Out:
#     name       city country  weight  height        bmi
# 0    pks       Pune   india      74    1.74  24.441802
# 1  Soham     London      Uk      78    1.78  24.618104
# 2   Arti  Stockholm  sweden      61    1.61  23.533043

# %%
data_df['bmi'] = data_df['bmi'].round(2)
data_df    #bmi short means make bmi round fig
# Out:
#     name       city country  weight  height    bmi
# 0    pks       Pune   india      74    1.74  24.44
# 1  Soham     London      Uk      78    1.78  24.62
# 2   Arti  Stockholm  sweden      61    1.61  23.53

# %%
data_df['Oldyear'] = ['1769','1985','1990']
data_df
# Out:
#     name       city country  weight  height    bmi Oldyear
# 0    pks       Pune   india      74    1.74  24.44    1769
# 1  Soham     London      Uk      78    1.78  24.62    1985
# 2   Arti  Stockholm  sweden      61    1.61  23.53    1990

# %%
curr_yr = pd.Series(2024,index=[0,1,2])
curr_yr
# Out:
# 0    2024
# 1    2024
# 2    2024
# dtype: int64

# %%
data_df['curr_yr'] = curr_yr
data_df
# Out:
#     name       city country  weight  height    bmi Oldyear  curr_yr
# 0    pks       Pune   india      74    1.74  24.44    1769     2024
# 1  Soham     London      Uk      78    1.78  24.62    1985     2024
# 2   Arti  Stockholm  sweden      61    1.61  23.53    1990     2024

# %%
#data_df['age'] = data_df['curr_yr'] - data_df['Oldyear']
#data_df

# %%
data_df['Oldyear'].dtype
# Out:
# dtype('O')

# %%
import numpy as np
data_df['Oldyear']= data_df['Oldyear'].astype(np.int16) # to make old year string into int

# %%
data_df['Oldyear'].dtype
# Out:
# dtype('int16')

# %%
data_df['age'] = data_df['curr_yr'] - data_df['Oldyear']
data_df
# Out:
#     name       city country  weight  height    bmi  Oldyear  curr_yr  age
# 0    pks       Pune   india      74    1.74  24.44     1769     2024  255
# 1  Soham     London      Uk      78    1.78  24.62     1985     2024   39
# 2   Arti  Stockholm  sweden      61    1.61  23.53     1990     2024   34

# %%
data_df.loc[data_df['age']>120] # to find any data based on situation
# Out:
#   name  city country  weight  height    bmi  Oldyear  curr_yr  age
# 0  pks  Pune   india      74    1.74  24.44     1769     2024  255

# %%
data_df['age']=data_df['age'].astype(np.float32) #change data type int to float
data_df
# Out:
#     name       city country  weight  height    bmi  Oldyear  curr_yr    age
# 0    pks       Pune   india      74    1.74  24.44     1769     2024  255.0
# 1  Soham     London      Uk      78    1.78  24.62     1985     2024   39.0
# 2   Arti  Stockholm  sweden      61    1.61  23.53     1990     2024   34.0

# %%
data_df.loc[data_df['age']>120 ,'age']= 36.5 #update the data
data_df
# Out:
#     name       city country  weight  height    bmi  Oldyear  curr_yr   age
# 0    pks       Pune   india      74    1.74  24.44     1769     2024  36.5
# 1  Soham     London      Uk      78    1.78  24.62     1985     2024  39.0
# 2   Arti  Stockholm  sweden      61    1.61  23.53     1990     2024  34.0

# %% [markdown]
# ## Read data from csv file

# %%
data_path ='./asp/movie_rating.csv'
data_df = pd.read_csv(data_path)
data_df.head() #to print first 5lines only from table
# Out:
#                                                 Name  Year  Rating  \
# 0                                       Sunset Blvd.  1950     8.7
# 1                                12 Angry Men (1957)  1957     8.9
# 2  Dr. Strangelove or: How I Learned to Stop Worr...  1964     8.5
# 3                                      The Godfather  1972     9.2
# 4                      The Godfather: Part II (1974)  1974     9.1
#
#                                          Description Genre_1    Genre_2  \
# 0  A hack screenwriter writes a screenplay for a ...   Drama  Film-Noir
# 1  A dissenting juror in a murder trial slowly ma...   Crime      Drama
# 2  An insane general triggers a path to nuclear h...  Comedy        NaN
# 3   "The aging patriarch of an organized crime dy...   Crime      Drama
# 4  The early life and career of Vito Corleone in ...   Crime      Drama
#
#   Genre_3 Certificate  Runtime
# 0     NaN    APPROVED      110
# 1     NaN    APPROVED       96
# 2     NaN    APPROVED       95
# ...

# %%
data_df.columns #numpy helps to identify columns in file
# Out:
# Index(['Name', 'Year', 'Rating', 'Description', 'Genre_1', 'Genre_2',
#        'Genre_3', 'Certificate', 'Runtime'],
#       dtype='object')

# %%
data_df.info() #numpy helps to identify whats data is in file.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         10 non-null     object
#  1   Year         10 non-null     int64
#  2   Rating       10 non-null     float64
#  3   Description  10 non-null     object
#  4   Genre_1      10 non-null     object
#  5   Genre_2      9 non-null      object
#  6   Genre_3      2 non-null      object
#  7   Certificate  10 non-null     object
#  8   Runtime      10 non-null     int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 848.0+ bytes

# %%
data_df.dtypes
# Out:
# Name            object
# Year             int64
# Rating         float64
# Description     object
# Genre_1         object
# Genre_2         object
# Genre_3         object
# Certificate     object
# Runtime          int64
# dtype: object

# %%
data_df.xs(2) #shows complete 3rd row
# Out:
# Name           Dr. Strangelove or: How I Learned to Stop Worr...
# Year                                                        1964
# Rating                                                       8.5
# Description    An insane general triggers a path to nuclear h...
# Genre_1                                                   Comedy
# Genre_2                                                      NaN
# Genre_3                                                      NaN
# Certificate                                             APPROVED
# Runtime                                                       95
# Name: 2, dtype: object

# %%
data_df.iloc[2] #we can locatate value of specific index in iloc also
# Out:
# Name           Dr. Strangelove or: How I Learned to Stop Worr...
# Year                                                        1964
# Rating                                                       8.5
# Description    An insane general triggers a path to nuclear h...
# Genre_1                                                   Comedy
# Genre_2                                                      NaN
# Genre_3                                                      NaN
# Certificate                                             APPROVED
# Runtime                                                       95
# Name: 2, dtype: object

# %%
data_df.iloc[2]['Rating']
# Out:
# np.float64(8.5)

# %%
data_df.loc[2,'Description'] #only passing index and column discription
# Out:
# 'An insane general triggers a path to nuclear holocaust that a war room full of politicians and generals frantically try to stop.'

# %%
data_df.describe() #understand range of data
# Out:
#              Year     Rating     Runtime
# count    10.00000  10.000000   10.000000
# mean   1978.80000   8.870000  143.700000
# std      19.35516   0.286938   39.763328
# min    1950.00000   8.500000   95.000000
# 25%    1966.00000   8.625000  110.750000
# 50%    1974.50000   8.900000  147.000000
# 75%    1994.00000   9.075000  169.750000
# max    2008.00000   9.300000  202.000000

# %%
data_df[data_df['Rating']>9]
# Out:
#                             Name  Year  Rating  \
# 3                  The Godfather  1972     9.2
# 4  The Godfather: Part II (1974)  1974     9.1
# 6       The Shawshank Redemption  1994     9.3
#
#                                          Description Genre_1 Genre_2 Genre_3  \
# 3   "The aging patriarch of an organized crime dy...   Crime   Drama     NaN
# 4  The early life and career of Vito Corleone in ...   Crime   Drama     NaN
# 6  Two imprisoned men bond over a number of years...   Crime   Drama     NaN
#
#   Certificate  Runtime
# 3           R      175
# 4           R      202
# 6           R      142

# %%
data_df[data_df.Rating > 9] #slice data frame based on value any column want to access -> help of (.)
# Out:
#                             Name  Year  Rating  \
# 3                  The Godfather  1972     9.2
# 4  The Godfather: Part II (1974)  1974     9.1
# 6       The Shawshank Redemption  1994     9.3
#
#                                          Description Genre_1 Genre_2 Genre_3  \
# 3   "The aging patriarch of an organized crime dy...   Crime   Drama     NaN
# 4  The early life and career of Vito Corleone in ...   Crime   Drama     NaN
# 6  Two imprisoned men bond over a number of years...   Crime   Drama     NaN
#
#   Certificate  Runtime
# 3           R      175
# 4           R      202
# 6           R      142

# %% [markdown]
# ## DataFrame Functions

# %%
num_df = pd.DataFrame(np.random.randn(100,4),
                      columns= list('ABCD'))    #make dataframe to take random numbers and make column abcd to it
num_df.head()
# Out:
#           A         B         C         D
# 0 -0.396751  1.551418 -0.360500 -2.711604
# 1 -1.024301 -0.520967  0.330503  0.688070
# 2  0.173435 -0.000321 -0.782280  1.254278
# 3  1.255457  2.075782 -1.040041  0.105819
# 4 -0.331192 -0.296518 -0.511875 -0.170761

# %%
num_df.mean() #mean values of each column
# Out:
# A   -0.005008
# B    0.167459
# C   -0.062492
# D    0.052408
# dtype: float64

# %%
num_df.mean(axis=1)[:4] #mean of first 4 rows
# Out:
# 0   -0.479359
# 1   -0.131674
# 2    0.161278
# 3    0.599254
# dtype: float64

# %%
num_df.std() #it will provide vertically without access std deviation
# Out:
# A    1.012169
# B    1.022156
# C    0.968469
# D    1.007037
# dtype: float64

# %%
num_df.max() #max numbers vertically
# Out:
# A    2.844963
# B    2.987365
# C    2.350317
# D    2.305551
# dtype: float64

# %%
for key,group in data_df.groupby('Rating'):
    print('key =',key,'\n',group[['Rating','Year','Runtime']])
# Out:
# key = 8.5
#     Rating  Year  Runtime
# 2     8.5  1964       95
# 5     8.5  1975      198
# key = 8.6
#     Rating  Year  Runtime
# 8     8.6  2000      113
# key = 8.7
#     Rating  Year  Runtime
# 0     8.7  1950      110
# key = 8.9
#     Rating  Year  Runtime
# 1     8.9  1957       96
# 7     8.9  1994      154
# key = 9.0
#     Rating  Year  Runtime
# 9     9.0  2008      152
# key = 9.1
#     Rating  Year  Runtime
# 4     9.1  1974      202
# key = 9.2
#     Rating  Year  Runtime
# 3     9.2  1972      175
# key = 9.3
#     Rating  Year  Runtime
# 6     9.3  1994      142

# %% [markdown]
# - csv
# - excel
# - hdf
# - sql
# - JSON
# - HTML
# - pickle

# %% [markdown]
# ## plotting

# %%
data_df.plot(figsize=(15,5))
# Out:
# <Axes: >

# %%
ax = data_df.plot(x = 'Year', figsize=(15,5))

# %%
ax = data_df.plot.bar(x = 'Year', figsize=(15,5))

# %%
ax = data_df.plot.bar(x = 'Year',stacked= True,figsize=(15,5))

# %%
timeseries = pd.Series(np.random.randn(100), #100 random list
                       index=pd.date_range('1/1/2010',periods=100)) #assign date as index to rows
ts_df = pd.DataFrame(np.random.randn(100,4), #radom 100 rows and 4 column
                     index = timeseries.index,#passing date as index of row
                     columns = list('ABCD'))   #columns are abcd

# %%
ts_df.head()
# Out:
#                    A         B         C         D
# 2010-01-01  1.772010 -2.445979 -0.285427  0.276060
# 2010-01-02 -1.062433 -0.631506  0.761581 -1.270282
# 2010-01-03  0.322495 -0.460046  0.607165  1.705357
# 2010-01-04  1.446149  0.945753  0.703928  1.062004
# 2010-01-05 -0.143941  0.413031  0.425597 -1.263127

# %%
ax = ts_df.plot(figsize=(15,5))

# %%
ts_df = ts_df.cumsum()
ax = ts_df.plot(figsize=(15,5))

# %%
import matplotlib.pyplot as plt
ts_df.iloc[5].plot(kind= 'bar', figsize=(10,4))
plt.axhline(0, color = 'k') # k use for black color
plt.grid(True)

# %%
ts_df.iloc[:20].plot(kind= 'bar', figsize=(10,4), stacked=True)
plt.axhline(0, color = 'k') # k use for black color
plt.grid(True)

# %%
ax = ts_df.iloc[:20].plot(kind= 'bar', figsize=(10,4), stacked=True)
ax.set_xticklabels([pandas_datetime.strftime('%Y-%d-%m')      #for four digit of year = Y, date & month
                    for pandas_datetime in ts_df[:20].index])

plt.axhline(0, color = 'k') # k use for black color
plt.grid(True)

# %%
import seaborn as sns

sns.boxplot(data=ts_df, y='A')
# Out:
# <Axes: ylabel='A'>
